# %%
import numpy as np 
import pandas as pd
import statistics 
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from statistics import *
from matplotlib.gridspec import GridSpec

from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %% [markdown]
# # Load dataset

# %%
# Load the data into a Pandas DataFrame

df = pd.read_csv('abcdataset_cleaned.csv')

# %% [markdown]
# # Perform the EDA on the dataset

# %%
# get the dimensions or shape of the dataset

df.shape
# Out:
# (19951, 16)

# %%
# get the data types of all the variables / attributes in the dataset

df.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# tracking_number      object
# date                 object
# sender_id             int64
# sender_zipCode      float64
# receiver_id           int64
# receiver_address     object
# service              object
# quantity              int64
# actual_weight       float64
# rate                float64
# description          object
# buy_in_store        float64
# extra_charge        float64
# agent_id             object
# dtype: object

# %%
# return the first five records of the dataset

df.head(5)
# Out:
#    Unnamed: 0     id tracking_number        date  sender_id  sender_zipCode  \
# 0           0  26838      ABC-018111  2021-09-05       5249         75040.0
# 1           1  26835      ABC-018108  2021-09-05       2357         75098.0
# 2           2  26834      ABC-018107  2021-09-05       2357         75098.0
# 3           3  26832      ABC-018105  2021-09-05       7188         75042.0
# 4           4  26831      ABC-018104  2021-09-05        166         79761.0
#
#    receiver_id receiver_address service  quantity  actual_weight  rate  \
# 0        15267          DA NANG    TINH         1            7.4   4.5
# 1        12053          SAI GON  SAIGON         1           17.4   3.5
# 2         2999          SAI GON  SAIGON         1           12.0   3.5
# 3        13168       TIEN GIANG    TINH         1            2.0   4.5
# 4          168       BINH THUAN    TINH         2           94.0   4.5
#
#                                          description  buy_in_store  \
# 0                                         loc ensure          57.0
# 1                               snack chocolate food           0.0
# 2                                         snack food           0.0
# 3                                           vitamins           0.0
# 4  iphone used imei 359497080983070 snack milk po...           0.0
#
#    extra_charge agent_id
# 0           0.0      ABC
# 1           0.0      ABC
# 2           0.0      ABC
# 3          36.0      ABC
# 4          70.0      ABC

# %%
# return the summary statistics of the numeric variables / attributes in the dataset

df.describe()
# Out:
#          Unnamed: 0            id     sender_id  sender_zipCode   receiver_id  \
# count  19951.000000  19951.000000  19951.000000    19951.000000  19951.000000
# mean   11001.479525  14632.965165   4136.043707    58969.626685   7544.727633
# std     6304.165735   6947.853448   2518.844245    24148.596822   3912.769104
# min        0.000000   2206.000000      2.000000     2151.000000      1.000000
# 25%     5583.500000   8730.500000   2052.000000    22180.000000   4662.500000
# 50%    10995.000000  14482.000000   4208.000000    75040.000000   7465.000000
# 75%    16416.500000  20451.500000   6082.500000    75074.000000  10565.500000
# max    21893.000000  26838.000000   9285.000000    99762.000000  15267.000000
#
#            quantity  actual_weight          rate  buy_in_store  extra_charge
# count  19951.000000   19951.000000  19951.000000  19951.000000  19951.000000
# mean       1.056689      20.659347      4.385973     14.524478     13.365527
# std        0.553634      23.065253      1.913032     52.255303     60.621173
# min        1.000000       0.000000      1.500000   -410.000000  -3475.000000
# 25%        1.000000       9.000000      3.500000      0.000000      0.000000
# 50%        1.000000      15.000000      4.500000      0.000000      0.000000
# 75%        1.000000      25.925000      4.500000      0.000000     10.000000
# max       47.000000    1392.000000    130.000000   2595.000000   4176.000000

# %%
# class distribution i.e. how many records are in each class

print(df.groupby('agent_id').size())
# Out:
# agent_id
# ABC      12943
# ABCVN        1
# LTM        304
# NEW        746
# NGO        218
# QUY       5715
# VNC         24
# dtype: int64

# %%
# plot histogram of each numeric variable / attribute in the data set

df.hist(figsize=(12, 8))
pyplot.show()

# %%
# generate density plots of each numeric variable / attribute in the data set

df.plot(kind = 'density', subplots=True, layout=(3, -1), sharex=False, legend=True, fontsize=1,
figsize=(12, 16))
pyplot.show()

# %%
# generate box plots of each numeric variable / attribute in the data set

df.plot(kind = 'box', subplots = True, layout = (3,-1), sharex=False, figsize=(12,8))
pyplot.show()

# %%
# generate scatter plot matrix of each numeric variable / attribute in the data set

scatter_matrix(df, alpha=0.8, figsize=(15, 15))
pyplot.show()
