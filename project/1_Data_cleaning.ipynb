# %%
import pandas as pd

# %% [markdown]
# # read the dataset

# %%
df_raw = pd.read_csv('abcdataset_raw.csv')
df_raw
# Out:
#           id tracking_number        date  sender_id  sender_zipCode  \
# 0      26838      ABC-018111    9/5/2021       5249         75040.0
# 1      26835      ABC-018108    9/5/2021       2357         75098.0
# 2      26834      ABC-018107    9/5/2021       2357         75098.0
# 3      26832      ABC-018105    9/5/2021       7188         75042.0
# 4      26831      ABC-018104    9/5/2021        166         79761.0
# ...      ...             ...         ...        ...             ...
# 21889   2210      ABC-001540  12/20/2019       2996         75042.0
# 21890   2209      ABC-001539  12/20/2019        218         75149.0
# 21891   2208      ABC-001538  12/20/2019       3045         75075.0
# 21892   2207      ABC-001537  12/20/2019       2794         75081.0
# 21893   2206      ABC-001536  12/20/2019       3095         75040.0
#
#        receiver_id receiver_address service  quantity actual_weight  rate  \
# 0            15267          DA NANG    TINH         1           7.4   4.5
# ...

# %% [markdown]
# dataset's shape

# %%
df_raw.shape
# Out:
# (21894, 15)

# %% [markdown]
# # replace empty cells by 0

# %%
df_raw.fillna(0, inplace = True)
df_raw
# Out:
#           id tracking_number        date  sender_id  sender_zipCode  \
# 0      26838      ABC-018111    9/5/2021       5249         75040.0
# 1      26835      ABC-018108    9/5/2021       2357         75098.0
# 2      26834      ABC-018107    9/5/2021       2357         75098.0
# 3      26832      ABC-018105    9/5/2021       7188         75042.0
# 4      26831      ABC-018104    9/5/2021        166         79761.0
# ...      ...             ...         ...        ...             ...
# 21889   2210      ABC-001540  12/20/2019       2996         75042.0
# 21890   2209      ABC-001539  12/20/2019        218         75149.0
# 21891   2208      ABC-001538  12/20/2019       3045         75075.0
# 21892   2207      ABC-001537  12/20/2019       2794         75081.0
# 21893   2206      ABC-001536  12/20/2019       3095         75040.0
#
#        receiver_id receiver_address service  quantity actual_weight  rate  \
# 0            15267          DA NANG    TINH         1           7.4   4.5
# ...

# %%
df_raw.shape
# Out:
# (21894, 15)

# %% [markdown]
# # delete rows with id, tracking_number, date, sender_id, sender_zipCode, receiver_id, receiver_address, receiver_state, quantity, actual_weight, rate, total, description, agent_id have 0 value

# %%
index_zip = df_raw[df_raw['sender_zipCode'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['id'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['tracking_number'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['date'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['sender_id'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['receiver_id'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['receiver_address'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['service'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['quantity'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['actual_weight'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['rate'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['description'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['agent_id'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %%
index_zip = df_raw[df_raw['description'] == 0].index
df_raw.drop(index_zip, inplace = True)

# %% [markdown]
# # new dataset and its shape

# %%
new_df = df_raw
new_df.shape
# Out:
# (19951, 15)

# %% [markdown]
# # cleaning text in description, receiver_address and service columns

# %%
# !pip install stop_words
# Define function for tokenize and lemmatizing
from stop_words import get_stop_words
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer

# %%
new_df['description'] = new_df['description'].apply(lambda x: " ".join(x for x in str(x).split() if not x.isdigit() and not x.isspace()))
new_df['description'] = new_df['description'].str.replace('[^\w\s]','')
new_df['description'] = new_df['description'].str.lower()
new_df
# Out:
#           id tracking_number        date  sender_id  sender_zipCode  \
# 0      26838      ABC-018111    9/5/2021       5249         75040.0
# 1      26835      ABC-018108    9/5/2021       2357         75098.0
# 2      26834      ABC-018107    9/5/2021       2357         75098.0
# 3      26832      ABC-018105    9/5/2021       7188         75042.0
# 4      26831      ABC-018104    9/5/2021        166         79761.0
# ...      ...             ...         ...        ...             ...
# 21889   2210      ABC-001540  12/20/2019       2996         75042.0
# 21890   2209      ABC-001539  12/20/2019        218         75149.0
# 21891   2208      ABC-001538  12/20/2019       3045         75075.0
# 21892   2207      ABC-001537  12/20/2019       2794         75081.0
# 21893   2206      ABC-001536  12/20/2019       3095         75040.0
#
#        receiver_id receiver_address service  quantity actual_weight  rate  \
# 0            15267          DA NANG    TINH         1           7.4   4.5
# ...

# %%
new_df['receiver_address'] = new_df['receiver_address'].str.upper()

# %%
new_df['service'] = new_df['service'].str.upper()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19951 entries, 0 to 21893
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                19951 non-null  int64
#  1   tracking_number   19951 non-null  object
#  2   date              19951 non-null  object
#  3   sender_id         19951 non-null  int64
#  4   sender_zipCode    19951 non-null  float64
#  5   receiver_id       19951 non-null  int64
#  6   receiver_address  19951 non-null  object
#  7   service           19951 non-null  object
#  8   quantity          19951 non-null  int64
#  9   actual_weight     19951 non-null  object
#  10  rate              19951 non-null  float64
#  11  description       19951 non-null  object
#  12  buy_in_store      19951 non-null  float64
#  13  extra_charge      19951 non-null  float64
#  14  agent_id          19951 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 2.4+ MB

# %% [markdown]
# # change datatype for date, actual_weight, buy_in_store

# %%
new_df['date'] = new_df['date'].astype('datetime64[ns]')
new_df['actual_weight'] = new_df['actual_weight'].astype(float)
new_df['buy_in_store'] = new_df['buy_in_store'].astype(float)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19951 entries, 0 to 21893
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                19951 non-null  int64
#  1   tracking_number   19951 non-null  object
#  2   date              19951 non-null  datetime64[ns]
#  3   sender_id         19951 non-null  int64
#  4   sender_zipCode    19951 non-null  float64
#  5   receiver_id       19951 non-null  int64
#  6   receiver_address  19951 non-null  object
#  7   service           19951 non-null  object
#  8   quantity          19951 non-null  int64
#  9   actual_weight     19951 non-null  float64
#  10  rate              19951 non-null  float64
#  11  description       19951 non-null  object
#  12  buy_in_store      19951 non-null  float64
#  13  extra_charge      19951 non-null  float64
#  14  agent_id          19951 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(5)
# ...

# %% [markdown]
# # save a cleaned dataset into a new file

# %%
new_df.to_csv('abcdataset_cleaned.csv')
